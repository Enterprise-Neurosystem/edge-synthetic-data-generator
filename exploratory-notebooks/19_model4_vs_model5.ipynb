# %%
# !pip install torch==1.11.0 
# !pip install git+https://github.com/gretelai/gretel-synthetics.git
# Out:
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp38-cp38-manylinux1_x86_64.whl (750.6 MB)
#      |██████████████▌                 | 339.2 MB 173.4 MB/s eta 0:00:03
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 750.6 MB 164.9 MB/s
# Requirement already satisfied: typing-extensions in /opt/app-root/lib/python3.8/site-packages (from torch==1.11.0) (4.0.1)
# Installing collected packages: torch
# Successfully installed torch-1.11.0
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.
# Collecting git+https://github.com/gretelai/gretel-synthetics.git
#   Cloning https://github.com/gretelai/gretel-synthetics.git to /tmp/pip-req-build-6g5nsasa
#   Running command git clone --filter=blob:none -q https://github.com/gretelai/gretel-synthetics.git /tmp/pip-req-build-6g5nsasa
#   Resolved https://github.com/gretelai/gretel-synthetics.git to commit 2ed9d31ce8f56afd1519c38859ab081e8cdef579
#   Preparing metadata (setup.py) ... done
# Collecting loky==2.9.0
#   Downloading loky-2.9.0-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 32.5 MB/s
# Requirement already satisfied: numpy>=1.18.0 in /opt/app-root/lib/python3.8/site-packages (from gretel-synthetics==0.18.1) (1.19.2)
# Requirement already satisfied: pandas>=1.1.0 in /opt/app-root/lib/python3.8/site-packages (from gretel-synthetics==0.18.1) (1.2.4)
# Collecting sentencepiece==0.1.96
#   Downloading sentencepiece-0.1.96-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 123.5 MB/s
# Collecting smart_open<6.0,>=2.1.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 114.1 MB/s
# Collecting tensorflow_privacy==0.7.3
#   Downloading tensorflow_privacy-0.7.3-py3-none-any.whl (251 kB)
#      |████████████████████████████████| 251 kB 128.5 MB/s
# Collecting tensorflow_probability==0.16.0
#   Downloading tensorflow_probability-0.16.0-py2.py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 118.3 MB/s
# Requirement already satisfied: tqdm<5.0 in /opt/app-root/lib/python3.8/site-packages (from gretel-synthetics==0.18.1) (4.62.3)
# Requirement already satisfied: cloudpickle in /opt/app-root/lib/python3.8/site-packages (from loky==2.9.0->gretel-synthetics==0.18.1) (1.5.0)
# Requirement already satisfied: attrs>=21.2.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (21.4.0)
# Collecting tensorflow-estimator>=2.3.0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 120.9 MB/s
# Requirement already satisfied: scipy>=0.17 in /opt/app-root/lib/python3.8/site-packages (from tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (1.6.2)
# Collecting tensorflow-datasets>=4.4.0
#   Downloading tensorflow_datasets-4.6.0-py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 110.1 MB/s
# Collecting dm-tree~=0.1.1
#   Downloading dm_tree-0.1.7-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 129.9 MB/s
# Collecting mpmath
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      |████████████████████████████████| 532 kB 108.3 MB/s
# Requirement already satisfied: decorator in /opt/app-root/lib/python3.8/site-packages (from tensorflow_probability==0.16.0->gretel-synthetics==0.18.1) (5.1.1)
# Collecting absl-py
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 134.9 MB/s
# Collecting gast>=0.3.2
#   Downloading gast-0.5.3-py3-none-any.whl (19 kB)
# Requirement already satisfied: six>=1.10.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow_probability==0.16.0->gretel-synthetics==0.18.1) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.1.0->gretel-synthetics==0.18.1) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=1.1.0->gretel-synthetics==0.18.1) (2.8.2)
# Collecting etils[epath]
#   Downloading etils-0.7.1-py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 135.0 MB/s
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: toml in /opt/app-root/lib/python3.8/site-packages (from tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (0.10.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (2.27.1)
# Requirement already satisfied: dill in /opt/app-root/lib/python3.8/site-packages (from tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (0.3.4)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.9.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 96.6 MB/s
# Requirement already satisfied: termcolor in /opt/app-root/lib/python3.8/site-packages (from tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (1.1.0)
# Requirement already satisfied: importlib-resources in /opt/app-root/lib/python3.8/site-packages (from tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (5.4.0)
# Requirement already satisfied: protobuf>=3.12.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (3.19.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (3.3)
# Requirement already satisfied: typing_extensions in /opt/app-root/lib/python3.8/site-packages (from etils[epath]->tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (4.0.1)
# Requirement already satisfied: zipp in /opt/app-root/lib/python3.8/site-packages (from etils[epath]->tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (3.7.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-metadata->tensorflow-datasets>=4.4.0->tensorflow_privacy==0.7.3->gretel-synthetics==0.18.1) (1.54.0)
# Building wheels for collected packages: gretel-synthetics, promise
#   Building wheel for gretel-synthetics (setup.py) ... done
#   Created wheel for gretel-synthetics: filename=gretel_synthetics-0.18.1-py3-none-any.whl size=88436 sha256=a737876ae70176fdb95f02125e8f9118c30e8c4dfee653ffdda466c9729bba31
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q4x9ejr6/wheels/07/d2/1a/f3fb53902b23fb200d2eb6e9cb5f9d32346bc9af2c5c0a6b1b
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21503 sha256=d62d82f2c3b887079df3fb8535df4d351d10647ac353a01a1035c72db3e325f0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q4x9ejr6/wheels/54/aa/01/724885182f93150035a2a91bce34a12877e8067a97baaf5dc8
# Successfully built gretel-synthetics promise
# Installing collected packages: etils, absl-py, tensorflow-metadata, promise, gast, dm-tree, tensorflow-probability, tensorflow-estimator, tensorflow-datasets, mpmath, tensorflow-privacy, smart-open, sentencepiece, loky, gretel-synthetics
# Successfully installed absl-py-1.2.0 dm-tree-0.1.7 etils-0.7.1 gast-0.5.3 gretel-synthetics-0.18.1 loky-2.9.0 mpmath-1.2.1 promise-2.3 sentencepiece-0.1.96 smart-open-5.2.1 tensorflow-datasets-4.6.0 tensorflow-estimator-2.9.0 tensorflow-metadata-1.9.0 tensorflow-privacy-0.7.3 tensorflow-probability-0.16.0
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as md
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from pickle import dump, load
from skimage.util.shape import view_as_windows

import torch

from gretel_synthetics.timeseries_dgan.dgan import DGAN
from gretel_synthetics.timeseries_dgan.config import DGANConfig, OutputType

# %%
slice0 = pd.read_csv('../data/kagglePump/full_slice0.csv') 
slice1 = pd.read_csv('../data/kagglePump/full_slice1.csv') 
slice2 = pd.read_csv('../data/kagglePump/full_slice2.csv')
slice3 = pd.read_csv('../data/kagglePump/full_slice3.csv') 
slice4 = pd.read_csv('../data/kagglePump/full_slice4.csv')
slice5 = pd.read_csv('../data/kagglePump/full_slice5.csv') 
slice6 = pd.read_csv('../data/kagglePump/full_slice6.csv') 

print(slice0.shape, slice1.shape, slice2.shape, slice3.shape, slice4.shape, slice5.shape, slice6.shape)
# Out:
# (2161, 55) (2161, 55) (2161, 55) (2161, 55) (2161, 55) (2161, 55) (2161, 55)

# %%
slices_list = [slice0, slice1, slice2, slice3, slice4, slice5, slice6]

slices_list.pop(4)

print(len(slices_list))
# Out:
# 6

# %%
COLS_TO_DROP = ['Unnamed: 0','sensor_00', 'sensor_15', 
                'sensor_50', 'sensor_51']
cleanup_nums = {"machine_status": {"NORMAL": 0,
                                   "BROKEN": 1,
                                   "RECOVERING":2}}

for sl in slices_list:
    sl['timestamp']= pd.to_datetime(sl['timestamp']) # cast to datatype
    sl = sl.drop(COLS_TO_DROP,axis=1, inplace=True) # drop cols

for sl in slices_list:
    sl = sl.replace(cleanup_nums)

for sl in slices_list:
    sl = sl.dropna(axis=0, inplace=True) # drop nans

# %%
# set up DGAN config.
config = DGANConfig(
    max_sequence_len=720,
    sample_len=20, # trying a larger sample_len
    batch_size=300,
    apply_feature_scaling=True, 
    apply_example_scaling=False,
    use_attribute_discriminator=False,
    generator_learning_rate=1e-4,
    discriminator_learning_rate=1e-4,
    epochs=10000)

model = DGAN(config)

# %%
# loading model 4 and 5
model4 = model.load("../models/dgan_model_4_48_sensors.pt",  map_location=torch.device('cpu'))
model5 = model.load("../models/dgan_model_5_48_sensors.pt",  map_location=torch.device('cpu'))

# %%
# Generate synthetic data - this ran near instantly
_, synthetic_features4 = model4.generate_numpy(1000)
_, synthetic_features5 = model5.generate_numpy(1000)

# %%
# 1000 samples of 720 cols x 49 rows
synthetic_features4.shape 
synthetic_features5.shape
# Out:
# (1000, 720, 49)

# %%
sensor_cols = slice0.columns
sensor_cols = sensor_cols[1:]

# %%
synthetic_df_4 = pd.DataFrame(synthetic_features4.reshape(-1, synthetic_features4.shape[2]), columns=sensor_cols)
synthetic_df_5 = pd.DataFrame(synthetic_features5.reshape(-1, synthetic_features5.shape[2]), columns=sensor_cols)

# %%
# Concatenating list of dfs into one large one
slices_list
real_slices=pd.concat(slices_list) 
real_slices.drop(['timestamp'], axis=1, inplace=True)
real_slices.head()
# Out:
#    sensor_01  sensor_02  sensor_03  sensor_04  sensor_05  sensor_06  \
# 0   50.95486  51.258678  44.140625   640.3936   83.42505   13.43316
# 1   50.95486  51.258680  44.140630   645.6019   82.65776   13.38252
# 2   51.04166  51.302080  44.227430   627.8936   83.92866   13.34635
# 3   50.95486  51.258680  44.227428   639.6991   82.42686   13.41146
# 4   50.86805  51.258680  44.227428   641.6666   84.44931   13.43316
#
#    sensor_07  sensor_08  sensor_09  sensor_10  ...  sensor_41  sensor_42  \
# 0   16.42795   15.33565   15.05353   41.28502  ...   40.10416   39.06250
# 1   16.42795   15.49479   15.05353   40.72804  ...   40.10416   39.32291
# 2   16.42795   15.37182   15.16204   41.02427  ...   39.58333   39.32291
# 3   16.42795   15.37182   15.05353   40.62917  ...   39.32291   39.06250
# 4   16.42795   15.61777   15.08247   41.24120  ...   39.06250   39.06250
#
#    sensor_43  sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  \
# 0   43.48958   41.08796   43.40278  41.956020  41.087960   182.5810
# 1   44.01041   41.66667   43.40278  41.666670  40.798610   186.3426
# 2   44.01041   41.95602   43.11343  41.087960  40.798611   187.2106
# 3   44.27083   41.95602   43.11343  41.087963  40.798611   184.8958
# 4   44.79166   41.95602   42.53472  41.087963  40.798610   179.9769
#
#    sensor_49  machine_status
# 0   72.04861             0.0
# 1   71.46991             0.0
# 2   71.46991             0.0
# 3   71.18056             0.0
# 4   71.18056             0.0
#
# [5 rows x 49 columns]

# %% [markdown]
# Comparing the accuracy synthetic data 4 and synthetic data 5 to real data:
# I. Correlations
# II. Distributions
# III. PCA

# %% [markdown]
# I. Correlations
# a) Correlation matrices for real, synthetic 4, and synthetic 5 data
# b) Correlation matrices for the differences between real and synthetic data
# c) Correlations between real and synthetic

# %%
# Correlation matrices: real,synthetic 4,synthetic 5
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,5))
sns.heatmap(real_slices.corr(),cmap='Greens',ax=ax1)
sns.heatmap(synthetic_df_4.corr(),cmap='Blues',ax=ax2)
sns.heatmap(synthetic_df_5.corr(), cmap="BuPu",ax=ax3)

ax1.set_title('Real Data')
ax2.set_title('Synthetic Data 4')
ax3.set_title('Synthetic Data 5')
plt.show()

# %%
# Let check for differences in correlation
real_synthetic4_corr = (real_slices.corr()-synthetic_df_4.corr()).abs()
real_synthetic5_corr = (real_slices.corr()-synthetic_df_4.corr()).abs()

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,5))
sns.heatmap(real_synthetic4_corr,cmap='viridis',ax=ax1)
sns.heatmap(real_synthetic5_corr,cmap='magma',ax=ax2)
# Out:
# <AxesSubplot:>

# %%
# Autocorrelations
real_slices.corrwith(synthetic_df_4)
# Out:
# sensor_01        -0.066254
# sensor_02        -0.002999
# sensor_03        -0.066201
# sensor_04         0.045009
# sensor_05        -0.057820
# sensor_06         0.008726
# sensor_07        -0.008661
# sensor_08         0.015459
# sensor_09         0.023413
# sensor_10         0.040029
# sensor_11         0.003901
# sensor_12        -0.025645
# sensor_13        -0.020842
# sensor_14        -0.055014
# sensor_16        -0.002316
# sensor_17         0.083070
# sensor_18         0.031094
# sensor_19         0.069650
# sensor_20         0.048322
# sensor_21         0.053107
# sensor_22         0.000682
# sensor_23        -0.010510
# sensor_24         0.037709
# sensor_25         0.007753
# sensor_26         0.059270
# sensor_27         0.018550
# sensor_28         0.061528
# sensor_29         0.039390
# sensor_30        -0.046403
# sensor_31         0.084676
# sensor_32        -0.015402
# sensor_33        -0.067551
# sensor_34         0.112937
# sensor_35         0.079806
# sensor_36        -0.186041
# sensor_37        -0.046871
# sensor_38         0.026214
# sensor_39         0.013729
# sensor_40         0.107633
# sensor_41         0.041067
# sensor_42         0.040708
# sensor_43         0.103121
# sensor_44         0.126654
# sensor_45         0.072396
# sensor_46         0.019134
# sensor_47         0.048195
# sensor_48        -0.021690
# sensor_49         0.174149
# machine_status         NaN
# dtype: float64

# %%
real_slices.corrwith(synthetic_df_5)
# Out:
# sensor_01         0.054518
# sensor_02         0.058347
# sensor_03         0.052935
# sensor_04        -0.108692
# sensor_05        -0.024906
# sensor_06        -0.021167
# sensor_07        -0.011785
# sensor_08         0.005639
# sensor_09        -0.002626
# sensor_10        -0.022035
# sensor_11         0.027604
# sensor_12         0.119225
# sensor_13         0.062047
# sensor_14        -0.126827
# sensor_16        -0.101375
# sensor_17        -0.113447
# sensor_18        -0.126628
# sensor_19        -0.216322
# sensor_20        -0.218223
# sensor_21        -0.214526
# sensor_22        -0.000433
# sensor_23         0.006642
# sensor_24        -0.140774
# sensor_25        -0.041321
# sensor_26        -0.061108
# sensor_27        -0.009290
# sensor_28         0.011478
# sensor_29        -0.038281
# sensor_30        -0.001339
# sensor_31        -0.039523
# sensor_32         0.025216
# sensor_33        -0.108026
# sensor_34        -0.115333
# sensor_35        -0.076705
# sensor_36         0.213446
# sensor_37         0.018270
# sensor_38        -0.023540
# sensor_39        -0.022872
# sensor_40         0.040792
# sensor_41         0.011232
# sensor_42         0.056070
# sensor_43         0.060871
# sensor_44         0.137069
# sensor_45         0.019449
# sensor_46         0.040313
# sensor_47         0.042212
# sensor_48         0.033173
# sensor_49         0.225231
# machine_status         NaN
# dtype: float64

# %% [markdown]
# II. Distributions between of real and synthetic data
# a) Sensor 34
# b) Sensor 25
# c) Sensor 11
# d) Sensor 36

# %%
# Compare distributions of sensor_34 values
plt.subplot(1,2,1)                
plt.hist([real_slices['sensor_34'], synthetic_df_4['sensor_34']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 34 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 4")

plt.subplot(1,2,2)               
plt.hist([real_slices['sensor_34'], synthetic_df_5['sensor_34']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 34 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 5")
plt.legend()

plt.tight_layout()                
plt.show()

# %%
# Compare distributions of sensor_25 values
plt.subplot(1,2,1)                
plt.hist([real_slices['sensor_25'], synthetic_df_4['sensor_25']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 25 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 4")

plt.subplot(1,2,2)               
plt.hist([real_slices['sensor_25'], synthetic_df_5['sensor_25']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 25 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 5")
plt.legend()

plt.tight_layout()                
plt.show()

# %%
# Compare distributions of sensor_11 values
plt.subplot(1,2,1)                
plt.hist([real_slices['sensor_11'], synthetic_df_4['sensor_11']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 11 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 4")

plt.subplot(1,2,2)               
plt.hist([real_slices['sensor_11'], synthetic_df_5['sensor_11']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 11 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 5")
plt.legend()

plt.tight_layout()                
plt.show()

# %%
# Compare distributions of sensor_36 values
plt.subplot(1,2,1)                
plt.hist([real_slices['sensor_36'], synthetic_df_4['sensor_36']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 36 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 4")

plt.subplot(1,2,2)               
plt.hist([real_slices['sensor_36'], synthetic_df_5['sensor_36']], 
         label=["real", "synthetic"],
         bins=25,
         density=True)
plt.xlabel("Sensor 36 Values")
plt.ylabel("Density")
plt.title(" Real vs. Synthetic 5")
plt.legend()

plt.tight_layout()                
plt.show()

# %% [markdown]
# III. PCA, based on this [article](https://medium.com/@clever.tech.memes/comparing-similarity-of-two-datasets-using-pca-a-technical-review-of-principal-component-analysis-94e528e4b191)

# %%
# PCA 
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
pca = PCA(n_components=2)

real_slices_scaled = scaler.fit(real_slices[:-1]).transform(real_slices[:-1])
synthetic_df_4_scaled = scaler.fit(synthetic_df_4[:-1]).transform(synthetic_df_4[:-1])
synthetic_df_5_scaled = scaler.fit(synthetic_df_5[:-1]).transform(synthetic_df_5[:-1])

# %%
real_slices_covar = np.cov(np.transpose(np.array(real_slices_scaled)))
synthetic_df_4_covar = np.cov(np.transpose(np.array(synthetic_df_4_scaled)))
synthetic_df_5_covar = np.cov(np.transpose(np.array(synthetic_df_5_scaled)))
                                                                  
pca_real_slices = pca.fit(real_slices_covar).transform(real_slices_covar)
pca_synthetic_df_4 = pca.fit(synthetic_df_4_covar).transform(synthetic_df_4_covar)
pca_synthetic_df_5 = pca.fit(synthetic_df_5_covar).transform(synthetic_df_5_covar)

# %%
def components_to_corr(pca_array1,pca_array2):
    df1,df2 = pd.DataFrame(pca_array1, columns = ['comp1','comp2']), pd.DataFrame(pca_array2, columns = ['comp1','comp2'])
    df_vertically_appended1 = df1['comp1'].append(df1['comp2']).reset_index(drop=True)
    df_vertically_appended2 = df2['comp1'].append(df2['comp2']).reset_index(drop=True)
    return (np.corrcoef(df_vertically_appended1,df_vertically_appended2)[0,1])

# %%
print('The correlation between real data and synthetic data 4 is {}'.format(components_to_corr(pca_real_slices, pca_synthetic_df_4)))
print()
print('The correlation between real data and synthetic data 5 is {}'.format(components_to_corr(pca_real_slices, pca_synthetic_df_5)))
# Out:
# The correlation between real data and synthetic data 4 is -0.7204681192054534
#
# The correlation between real data and synthetic data 5 is -0.7294247754986976

# %% [markdown]
# Synthetic data 5 seems to be more strongly correlated with the real data compared to synthetic data 4.
